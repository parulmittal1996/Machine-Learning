# %%
import pandas as pd
import numpy as np
df = pd.read_csv("kc_house_data .csv")
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.drop(["id","date", "yr_built", "yr_renovated"], axis = 1, inplace = True)

df.head(2)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  zipcode      lat  \
# 0     0          3      7        1180              0    98178  47.5112
# 1     0          3      7        2170            400    98125  47.7210
#
#       long  sqft_living15  sqft_lot15
# 0 -122.257           1340        5650
# 1 -122.319           1690        7639

# %%
a = df.columns

# %%
df.shape
# Out:
# (21597, 17)

# %%
def outlier(data):
    a = df.columns
    for i in range(len(a)):
        d=data[a[i]]
        outlier1=[]
        data_mean = np.mean(d)
        data_std = np.std(d)
        threshold = 3
        for j in d:
            zscore = (j - data_mean)/data_std
        
            if(np.abs(zscore)> threshold):
                outlier1.append(j)
        for m in outlier1:
            data = data[data[data.columns[i]] !=m]
    return data

# %%
outlier(df)
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0       221900.0         3       1.00         1180      5650     1.0
# 1       538000.0         3       2.25         2570      7242     2.0
# 2       180000.0         2       1.00          770     10000     1.0
# 3       604000.0         4       3.00         1960      5000     1.0
# 4       510000.0         3       2.00         1680      8080     1.0
# 6       257500.0         3       2.25         1715      6819     2.0
# 7       291850.0         3       1.50         1060      9711     1.0
# 8       229500.0         3       1.00         1780      7470     1.0
# 9       323000.0         3       2.50         1890      6560     2.0
# 11      468000.0         2       1.00         1160      6000     1.0
# 12      310000.0         3       1.00         1430     19901     1.5
# 13      400000.0         3       1.75         1370      9680     1.0
# 14      530000.0         5       2.00         1810      4850     1.5
# ...

# %%
y = df.iloc[:,0]
x = df.iloc[:,1:18]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = .20, random_state = 0)

# %%
x_train.shape
# Out:
# (17277, 16)

# %%
y_train.shape
# Out:
# (17277,)

# %%
from sklearn.linear_model import LinearRegression
p = LinearRegression()

# %%
p.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pre = p.predict(x_test)

# %%
pre
# Out:
# array([ 887498.17185953,  707980.52418153,  993968.70009438, ...,
#         534004.33734289, 1026245.17181549,  162364.22279458])

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score
rmse = np.sqrt(mean_squared_error(y_test,pre))

# %%
rmse
# Out:
# 194589.94557326025

# %%
r2_score(y_test, pre)
# Out:
# 0.6783379432938377

# %%
print('Intercept: \n', p.intercept_)
print('Coefficients: \n', p.coef_)
# Out:
# Intercept:
#  -32475409.698074423
# Coefficients:
#  [-3.12160124e+04  2.54351175e+03  1.28942052e+02  1.31387834e-01
#  -2.46178997e+04  5.49995437e+05  6.43082470e+04  5.08454411e+04
#   7.85334203e+04  8.18414179e+01  4.71006339e+01 -4.32503806e+02
#   6.86127066e+05 -3.41045516e+05  2.01788223e+01 -3.94441243e-01]

# %%
pre1 = p.predict([[3,1.00,1180,5650,1.0,0,0,3,7,1180,0,98178,47.5112,-122.257,1340,5650]])

# %%
pre1
# Out:
# array([216979.20321063])
