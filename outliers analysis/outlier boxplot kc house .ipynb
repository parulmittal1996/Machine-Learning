# %%
import pandas as pd
data = pd.read_csv("kc_house_data .csv")
data.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
x = data["bedrooms"]

# %%
data.drop(["id","date", "yr_built", "yr_renovated"], axis = 1, inplace = True)

data.head(2)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  zipcode      lat  \
# 0     0          3      7        1180              0    98178  47.5112
# 1     0          3      7        2170            400    98125  47.7210
#
#       long  sqft_living15  sqft_lot15
# 0 -122.257           1340        5650
# 1 -122.319           1690        7639

# %%
import numpy as np
quartile1,quartile3=np.percentile(x,[25,75])

# %%
y = quartile1
y
# Out:
# 3.0

# %%
z = quartile3
z
# Out:
# 4.0

# %%
lower_limit = y - (1.5*(z-y))
lower_limit
# Out:
# 1.5

# %%
upper_limit = z + (1.5*(z-y))
upper_limit
# Out:
# 5.5

# %%
x = data["bathrooms"]

# %%
def outlier(data):
    out = []

    q1,q3=np.percentile(data,[25,75])
    l = q1 - (1.5*(q3-q1))
    u = q3 + (1.5*(q3-q1))
    for i in data:
        if(i>=u) or (i<=l):
            out.append(i)
    return(out)
outlier(x)
# Out:
# [4.5,
#  4.0,
#  4.0,
#  4.75,
#  5.0,
#  4.25,
#  4.5,
#  4.25,
#  3.75,
#  5.0,
#  4.0,
#  4.0,
#  4.25,
#  4.25,
#  4.25,
#  4.5,
#  4.5,
#  3.75,
#  4.5,
#  4.0,
#  4.5,
#  5.25,
#  4.0,
#  3.75,
#  4.5,
#  4.5,
#  4.25,
#  6.0,
#  3.75,
#  4.25,
#  4.0,
#  3.75,
#  3.75,
#  4.75,
#  5.0,
#  3.75,
#  3.75,
#  3.75,
#  5.0,
#  4.25,
#  3.75,
#  4.0,
#  4.25,
#  4.5,
#  3.75,
#  4.0,
#  3.75,
#  5.0,
#  3.75,
#  4.0,
#  3.75,
#  3.75,
#  4.25,
#  4.0,
#  4.25,
#  4.25,
#  4.5,
#  3.75,
#  4.0,
#  3.75,
#  5.0,
#  3.75,
#  0.5,
#  4.0,
#  5.0,
#  5.0,
#  4.5,
#  5.5,
#  4.25,
#  4.0,
#  4.5,
#  3.75,
#  3.75,
#  4.5,
#  3.75,
#  5.5,
#  4.25,
#  5.5,
#  5.25,
#  4.25,
#  4.0,
#  4.5,
#  3.75,
#  3.75,
#  3.75,
#  3.75,
#  4.25,
#  4.5,
#  4.75,
#  3.75,
#  3.75,
#  3.75,
#  3.75,
#  3.75,
#  4.5,
#  4.25,
#  4.0,
#  4.75,
#  4.75,
#  3.75,
#  4.5,
#  4.0,
#  3.75,
#  3.75,
#  4.0,
#  4.0,
#  3.75,
#  4.75,
#  4.5,
#  3.75,
#  6.75,
#  6.0,
#  4.5,
#  5.5,
#  4.5,
#  3.75,
#  4.0,
# ...

# %%
p =data.columns

# %%
p
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'zipcode', 'lat', 'long', 'sqft_living15',
#        'sqft_lot15'],
#       dtype='object')

# %%
def outlier(df):
    for i in range (len(p)):
        a = data[p[i]]
        q1,q3=np.percentile(df,[25,75])
        l = q1 - (1.5*(q3-q1))
        u = q3 + (1.5*(q3-q1))
        for j in df:
            if(j>=u) or (j<=l):
                data = data[p[i] !=j]
        return(data)
outlier(a)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-72-ed6c6a8041c0> in <module>
#       9                 data = data[p[i] !=j]
#      10         return(data)
# ---> 11 outlier(a)
#      12
#      13
#
# <ipython-input-72-ed6c6a8041c0> in outlier(df)
#       1 def outlier(df):
#       2     for i in range (len(p)):
# ----> 3         a = data[p[i]]
#       4         q1,q3=np.percentile(df,[25,75])
#       5         l = q1 - (1.5*(q3-q1))
#
# UnboundLocalError: local variable 'data' referenced before assignment

# %%
for i in range (len(a)):
    print(a[i])
    k=data[a[i]]
    p1,p2=np.percentile(k,[25,75])
    l=p1-1.5*(p2-p1)
    u=p2+1.5*(p2-p1)
    for j in k:
        if(j>=u) or (j<=l):
            data =  data[a[i] !=j]
    print(data)
# Out:
# 5650
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 5650
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-3cc2c21d12e6> in <module>
#       1 for i in range (len(a)):
# ...

# %%
p = data.drop
